# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.datasets import make_regression

# %%
make_regression(n_samples=2, n_features=1)
# Out:
# (array([[0.65205243],
#         [1.2516087 ]]),
#  array([45.32628054, 87.00338261]))

# %%
make_regression(n_samples=3, n_features=1)
# Out:
# (array([[-1.24987275],
#         [-0.04740816],
#         [-0.661411  ]]),
#  array([-85.72068517,  -3.25141922, -45.36190096]))

# %%
make_regression(n_samples=3, n_features=2)
# Out:
# (array([[ 0.52753736,  0.51213645],
#         [-0.16767859,  1.21274296],
#         [-2.42662951,  0.17203979]]),
#  array([  57.35194938,   41.03537114, -154.90254748]))

# %%
x, y = make_regression(n_samples=10, n_features=1)
plt.scatter(x,y)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x, model.coef_ * x + model.intercept_)

# %% [markdown]
# #Adaugare Noise(zgomot)

# %%
x, y = make_regression(n_samples=100, n_features=1, noise=10)
model = LinearRegression()
model.fit(x, y)
plt.scatter(x,y);
plt.plot(x, model.coef_ * x + model.intercept_)

# %%
model.predict([[1]])
# Out:
# array([10.67674708])

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x,y)
# Out:
# KNeighborsRegressor()

# %%
knn_model.predict([[1]])
# Out:
# array([12.37327556])
